# %%
import sys
sys.path.append('../src')

# %%
# Import the pipeline, utility function, and all custom transformers
from feature_engineering import (
    feature_pipeline,
    process_data_pipeline,
    AggregateFeatures,
    DateTimeFeatures,
    CategoricalEncoder,
    MissingValueHandler,
    Scaler
)

# Option 2: Use the pipeline on a DataFrame you already loaded
import pandas as pd
df = pd.read_csv('../data/raw/data.csv')
processed_df2 = feature_pipeline.fit_transform(df)
display(processed_df2.head())

# Option 3: Use individual transformers for custom steps
agg = AggregateFeatures()
df_agg = agg.fit_transform(df)

dt = DateTimeFeatures()
df_dt = dt.fit_transform(df)

cat = CategoricalEncoder()
df_cat = cat.fit_transform(df)

miss = MissingValueHandler(strategy='mean')
df_miss = miss.fit_transform(df)

scaler = Scaler(method='standard')
df_scaled = scaler.fit_transform(df)
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          0.0  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          0.0  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          0.0  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          0.0  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          0.0  ProviderId_4   ProductId_6
#
#       ProductCategory  ... PricingStrategy  FraudResult  \
# ...

# %%
import pandas as pd

# Load data.csv from the raw data directory
df_loaded = pd.read_csv('../data/raw/data.csv')
display(df_loaded.head())
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
processed_df = process_data_pipeline(raw_data_path='../data/raw', filename='data.csv')
print(processed_df)  #
# Out:
# Loading data from: d:\10Acadamy\Credit-Risk-Probability-Model\data\raw
# One-hot encoding columns: ['CurrencyCode', 'ProviderId', 'ProductId', 'ProductCategory', 'ChannelId']
# Label encoding columns: ['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId', 'TransactionStartTime']
#        TransactionId   BatchId  AccountId  SubscriptionId  CustomerId  \
# 0           1.097926 -0.015563   0.153713        1.668646    0.595070
# 1           1.013589 -0.571733   0.867190        0.346449    0.595070
# 2          -0.287613  0.469994   0.371965       -1.203089    0.807169
# 3           0.032862 -1.666100   0.996380       -1.227972    1.692827
# 4          -0.234164  0.056072   0.867190        0.346449    1.692827
# ...              ...       ...        ...             ...         ...
# 95657       1.456605  1.642207   0.867190        0.346449   -0.436764
# 95658       1.502341 -0.044970  -0.272024       -0.803828    0.184247
# ...
